# %%
#STUDENT RECORD MANAGEMENT PROGRAM

students = ["Aditya", "Souvik", "Sachin", "Aditya"]
details = {335629 : "Aditya", 789433 : "Souvik", 897654 : "Sachin", 435634 : "Aditya"}

#attendance percentage for Aditya
Aditya_percentage = ("Jan 76%","Feb 78%", "Mar 65%", "April 76%", "May 50%")

#attendance percentage for Souvik
Souvik_percentage = ("Jan 89%","Feb 66%", "Mar 76%", "April 09%", "May 10%")

#attendance percentage for Sachin
Sachin_percentage = ("Jan 56%","Feb 87%", "Mar 34%", "April 54%", "May 10%")

#attendance percentage for Sachin
Aditya2_percentage = ("Jan 90%","Feb 87%", "Mar 73%", "April 67%", "May 98%")

user = input("User type\n"
            "P. Parent\n"
            "T. Teacher\n")
if user == "P":
    greeting = "Hello, welcome "
    ERP = int(input("Enter student's ERP: "))
    name = details[ERP]
    print( greeting  + name + "'s parent")
    
    
    choice = int(input("What do you want to see today?\n"
           "1. Your children's attendace history\n"
           "2. Teacher's suggestion about your child\n"))
    if choice == 1:
        if ERP == 335629:
            print(f"Here is {name}'s attendance")
            print(Aditya_percentage)
        elif ERP == 789433:
            print(f"Here is {name}'s attendance")
            print(Souvik_percentage)
        elif ERP == 897654:
            print(f"Here is {name}'s attendance")
            print(Sachin_percentage)
        elif ERP == 435634:
            print(f"Here is {name}'s attendance")
            print(Aditya2_percentage)
        
    elif choice == 2:
        if ERP == 335629:
            print(f"Here is the Teacher's suggestions about {name}\n")
            aditya_file = open("Aditya.txt", "r")
            print(aditya_file.read())
            aditya_file.close()
    
        elif ERP == 789433:
            print(f"Here is the Teacher's suggestions about {name}\n")
            souvik_file = open("Souvik.txt", "r")
            print(souvik_file.read())
            souvik_file.close()
    
        elif ERP == 897654:
            print(f"Here is the Teacher's suggestions about {name}\n")
            sachin_file = open("Sachin.txt", "r")
            print(sachin_file.read())
            sachin_file.close()
        elif ERP == 435634:
            print(f"Here is the Teacher's suggestions about {name}\n")
            aditya2_file = open("Aditya2.txt", "r")
            print(aditya2_file.read())
            aditya2_file.close()

    else:
        print("Invalid input")

elif user == "T":
    print("Welcome Teacher!")
    choice = int(input("What do you want to do today?\n"
           "1. List of all the students\n"
           "2. Student details\n"
           "3. Count the no. of students with same name\n"
           "4. Add suggestion in the student's file\n"))
    if choice == 1:
        print(students)

    elif choice == 2:
        print("Details is in the form ERP : Name\n")
        print(details)

    elif choice == 3:
        print("Aditya :", students.count("Aditya"))

    elif choice == 4:
        n = int(input("Enter the ERP of the student on whom you want to add suggestions\n"))
        if n == 335629:
            print("Here is the Aditya's suggestion file\n")
            aditya_file = open("Aditya.txt", "a")
            new_suggestion = input("Write the suggestions you want to add about Aditya")
            (aditya_file.write(new_suggestion + "\n"))
            aditya_file.close()
            n_choice = input("Want to the suggestion file\n"
                             "yes\n"
                             "no\n")
            if n_choice == "yes":
                aditya_file = open("Aditya.txt", "r")
                print(aditya_file.read())
                aditya_file.close()
            elif n_choice == "no":
                print("Your work has done.")
    
        elif n == 789433:
            print("Here is the Souvik's suggestion file\n")
            souvik_file = open("Souvik.txt", "a")
            new_suggestion = input("Write the suggestions you want to add about Souvik")
            (souvik_file.write(new_suggestion + "\n"))
            souvik_file.close()
            n_choice = input("Want to the suggestion file\n"
                             "yes\n"
                             "no\n")
            if n_choice == "yes":
                souvik_file = open("Souvik.txt", "r")
                print(souvik_file.read())
                souvik_file.close()
            elif n_choice == "no":
                print("Your work has done.")
    
        elif n == 897654:
            print("Here is the Sachin's suggestion file\n")
            sachin_file = open("Sachin.txt", "a")
            new_suggestion = input("Write the suggestions you want to add about Sachin")
            (sachin_file.write(new_suggestion + "\n"))
            sachin_file.close()
            n_choice = input("Want to the suggestion file\n"
                             "yes\n"
                             "no\n")
            if n_choice == "yes":
                sachin_file = open("Sachin.txt", "r")
                print(sachin_file.read())
                sachin_file.close()
            elif n_choice == "no":
                print("Your work has done.")
# Out:
# User type
# P. Parent
# T. Teacher
#  T
# Welcome Teacher!
# What do you want to do today?
# 1. List of all the students
# 2. Student details
# 3. Count the no. of students with same name
# 4. Add suggestion in the student's file
#  3
# Aditya : 2
